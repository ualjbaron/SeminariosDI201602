# %% [markdown]
# <a href="https://colab.research.google.com/github/ualjbaron/SeminariosDI201602/blob/master/Utilidades.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Utilidades

# %%
ruta = "/datalab" #@param {type:"string"}
print(ruta) 
# !export ruta
# !cd /content/drive
# !pwd
# !ls -la
# Out:
# /datalab
# /content
# total 20
# drwxr-xr-x 1 root root 4096 Mar 13 09:30 .
# drwxr-xr-x 1 root root 4096 Mar 13 09:07 ..
# drwxr-xr-x 4 root root 4096 Mar  5 14:36 .config
# drwx------ 6 root root 4096 Mar 13 09:30 drive
# drwxr-xr-x 1 root root 4096 Mar  5 14:37 sample_data

# %%
# !cd /home
# !pwd
# Out:
# /content
